# %%
# Importing the libraries
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\ommic\Desktop\Spotify_Most_Streamed_Songs.csv") #Loading Dataset into Dataframe

# %%
#Dataset Summary
print(df)
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'danceability_%', 'valence_%',
#        'energy_%', 'instrumentalness_%'],
#       dtype='object')

# %%
rows = df.shape[0]
columns = df.shape[1]
print(f"Number of rows: {rows}")
print(f"Number of columns: {columns}")
# Out:
# Number of rows: 953
# Number of columns: 13

# %%
#First 5 rows in dataset
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  danceability_%  valence_%  energy_%  \
# ...

# %%
#Last 5 rows in dataset
df.tail()
# Out:
#                     track_name      artist(s)_name  artist_count  \
# 948               My Mind & Me        Selena Gomez             1
# 949  Bigger Than The Whole Sky        Taylor Swift             1
# 950       A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951              En La De Ella  Feid, Sech, Jhayco             3
# 952                      Alone           Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  danceability_%  valence_%  energy_%  \
# 948                  0   91473363              60         24        39
# ...

# %%
#Random 5 rows in dataset
df.sample(5)
# Out:
#                                  track_name           artist(s)_name  \
# 803                       PUFFIN ON ZOOTIEZ                   Future
# 741                              Angel Baby              Troye Sivan
# 218                 Karma (feat. Ice Spice)  Taylor Swift, Ice Spice
# 448  Let It Snow! Let It Snow! Let It Snow!              Dean Martin
# 937                              Circo Loco         Drake, 21 Savage
#
#      artist_count  released_year  released_month  released_day  \
# 803             1           2022               4            29
# 741             1           2021               9             9
# 218             2           2023               5            26
# 448             1           1959              11            16
# 937             2           2022              11             4
#
#      in_spotify_playlists  in_spotify_charts    streams  danceability_%  \
# 803                  2350                  0  254218729              88
# ...

# %%
#Info about dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   danceability_%        953 non-null    int64
#  10  valence_%             953 non-null    int64
#  11  energy_%              953 non-null    int64
#  12  instrumentalness_%    953 non-null    int64
# dtypes: int64(10), object(3)
# memory usage: 96.9+ KB

# %%
#Data Cleaning
df["streams"] = pd.to_numeric(df["streams"], errors='coerce')

# %%
df["streams"].info() #Invalid data cleaned from streams column
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 953 entries, 0 to 952
# Series name: streams
# Non-Null Count  Dtype
# --------------  -----
# 952 non-null    float64
# dtypes: float64(1)
# memory usage: 7.6 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               952 non-null    float64
#  9   danceability_%        953 non-null    int64
#  10  valence_%             953 non-null    int64
#  11  energy_%              953 non-null    int64
#  12  instrumentalness_%    953 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 96.9+ KB

# %%
print(df["streams"])
# Out:
# 0      141381703.0
# 1      133716286.0
# 2      140003974.0
# 3      800840817.0
# 4      303236322.0
#           ...
# 948     91473363.0
# 949    121871870.0
# 950     73513683.0
# 951    133895612.0
# 952     96007391.0
# Name: streams, Length: 953, dtype: float64

# %%
#Finding null values in dataset
df.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 1
# danceability_%          0
# valence_%               0
# energy_%                0
# instrumentalness_%      0
# dtype: int64

# %%
#Replacing null values in streams column with mean
mean = df['streams'].mean()
print(mean)
df['streams'] = df['streams'].fillna(mean)
# Out:
# 514137424.93907565

# %%
df.isnull().sum() #Null values removed from dataset
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# danceability_%          0
# valence_%               0
# energy_%                0
# instrumentalness_%      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    float64
#  9   danceability_%        953 non-null    int64
#  10  valence_%             953 non-null    int64
#  11  energy_%              953 non-null    int64
#  12  instrumentalness_%    953 non-null    int64
# dtypes: float64(1), int64(10), object(2)
# memory usage: 96.9+ KB

# %%
#Finding duplicated values in dataset
df.duplicated().sum()
# Out:
# 0

# %%
#Detecting Outliers in dataset
#Displaying Description of dataset
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts       streams  danceability_%  \
# count            953.000000         953.000000  9.530000e+02       953.00000
# mean            5200.124869          12.009444  5.141374e+08        66.96957
# std             7897.608990          19.575992  5.665592e+08        14.63061
# ...

# %%
#Boxplot
sns.boxplot(data=df[["danceability_%","energy_%","valence_%","instrumentalness_%"]])
plt.show()

# %%
#Boxplot
sns.boxplot(data=df[["artist_count","released_year","released_month","released_day"]])
plt.show()

# %%
#Boxplot
sns.boxplot(data=df[["in_spotify_playlists","in_spotify_charts","streams"]])
plt.show()

# %%
#Histogram
plt.hist(df["streams"])
plt.show()

# %%
#Scatter plot for detecting outliers
plt.scatter(df['track_name'], df['streams'])
plt.xlabel('Song Name')
plt.ylabel('streams')
plt.show()

# %%
# Plot histogram for streams
plt.figure(figsize=(10, 6))
plt.hist(df['streams'], bins=30, color='blue', alpha=0.7)
plt.title('Distribution of Streams')
plt.xlabel('Number of Streams')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# Scatter plot for Streams vs Danceability
plt.figure(figsize=(10, 6))
plt.scatter(df['danceability_%'], df['streams'], alpha=0.5)
plt.title('Streams vs Danceability')
plt.xlabel('Danceability %')
plt.ylabel('Number of Streams')
plt.show()

# %%
# Convert streams to integers (if necessary) - Multivariate analysis
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# Calculate total streams per artist
artist_streams = df.groupby('artist(s)_name')['streams'].sum().reset_index()

# Sort values to get top artists (optional)
top_artists = artist_streams.sort_values(by='streams', ascending=False).head(10)

# Plot pie chart for top artists
plt.figure(figsize=(10, 8))
plt.pie(top_artists['streams'], labels=top_artists['artist(s)_name'], autopct='%1.1f%%', startangle=90)
plt.title('Proportion of Total Streams by Top Artists')
plt.axis('equal')  # Equal aspect ratio ensures that pie chart is circular.
plt.show()

# %% [markdown]
# ### MATPLOTLIB

# %%
from matplotlib import pyplot as plt

# %%
# Basic Plotting with Matplotlib
x = df['released_year']
y = df['streams']

# %%
# Line plot of different songs streamed over the year
plt.plot(x, y, label='Streams over Year', color='blue')
plt.title('Streams of Songs Over Years')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.legend()
plt.show()

# %%
# Scatter plot
plt.scatter(x, y, color='red')
plt.title('Scatter Plot of Streams vs Released Year')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.show()

# %% [markdown]
# ### SEABORN

# %%
# Ignore warnings
import warnings
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
import seaborn as sns

# %%
# Basic Plotting with Seaborn
# Line plot using Seaborn
sns.lineplot(data=df, x='released_year', y='streams', label='Streams over Year', color='blue')
plt.title('Streams of Songs Over Years (Seaborn)')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.legend()
plt.show()

# %%
# Scatter plot using Seaborn
sns.scatterplot(data=df, x='released_year', y='streams', color='cyan')
plt.title('Scatter Plot of Streams vs Released Year (Seaborn)')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.show()

# %%
# Statistical Plots with Seaborn
# Box plot for streams by released year
sns.boxplot(data=df, x='released_year', y='streams')
plt.title('Box Plot of Streams by Released Year')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.xticks(rotation=45)
plt.show()

# %%
# Histogram for streams
sns.histplot(data=df, x='streams', bins=30)
plt.title('Histogram of Streams Distribution')
plt.xlabel('Number of Streams')
plt.ylabel('Frequency')
plt.show()

# %%
# Customization with Seaborn
sns.set_style('whitegrid')

# %%
# Re-plotting the line plot with new style
sns.lineplot(data=df, x='released_year', y='streams', label='Streams over Year', color='blue')
plt.title('Streams of Songs Over Years (Styled)')
plt.xlabel('Released Year')
plt.ylabel('Number of Streams')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df.head(32)
# Out:
#                                            track_name  \
# 0                 Seven (feat. Latto) (Explicit Ver.)
# 1                                                LALA
# 2                                             vampire
# 3                                        Cruel Summer
# 4                                      WHERE SHE GOES
# 5                                            Sprinter
# 6                                     Ella Baila Sola
# 7                                            Columbia
# 8                                            fukumean
# 9                                     La Bebe - Remix
# 10                                          un x100to
# 11                                          Super Shy
# 12                                            Flowers
# 13                                           Daylight
# 14                                          As It Was
# 15                                          Kill Bill
# ...

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df.columns
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'danceability_%', 'valence_%',
#        'energy_%', 'instrumentalness_%'],
#       dtype='object')

# %%
X = df[['artist_count','in_spotify_playlists','in_spotify_charts','danceability_%', 'valence_%', 'energy_%', 'instrumentalness_%']]
y = df['streams']  #Target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, train_size = 0.7, random_state = 42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(model.intercept_)
# Out:
# 358802049.1337223

# %%
coeff_df = pd.DataFrame(model.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                        Coefficient
# artist_count         -2.921230e+07
# in_spotify_playlists  5.268457e+04
# in_spotify_charts     4.191587e+06
# danceability_%        7.808992e+04
# valence_%             3.853361e+05
# energy_%             -2.316219e+06
# instrumentalness_%   -1.391606e+06

# %%
y_pred = model.predict(X_test)

# %%
print(y_pred)
# Out:
# [2.59693690e+09 2.03331468e+08 4.01899470e+08 6.71899620e+08
#  9.88977559e+08 6.17214321e+08 1.97697653e+08 4.13771854e+08
#  2.40869534e+08 2.34505610e+08 2.57191735e+08 2.43342706e+08
#  7.59411240e+08 3.76421915e+08 6.77057803e+08 5.00765150e+08
#  4.10201904e+08 4.37093865e+08 4.60236864e+08 4.42244111e+08
#  2.26034879e+08 3.06247086e+08 3.80125711e+08 2.29511185e+08
#  4.19878959e+08 2.00113807e+08 6.23498707e+08 2.47379853e+08
#  4.27725782e+08 5.26756012e+08 6.89115074e+08 1.51244426e+09
#  3.06454051e+08 6.88789821e+08 6.83715696e+08 4.54186868e+08
#  4.10677648e+08 4.32310831e+08 4.66463280e+08 2.59642650e+08
#  3.24004718e+08 2.19141135e+08 1.00736937e+09 8.26442517e+08
#  1.41770555e+09 4.15971611e+08 3.90129189e+08 3.55651897e+08
#  3.32215960e+08 1.02231882e+09 3.48961581e+08 5.44556892e+08
#  3.62154743e+08 3.17587996e+08 4.61572907e+08 1.98232231e+08
#  2.08783014e+08 2.27351855e+08 2.21278447e+08 2.28434910e+08
# ...

# %%
plt.scatter(y_test,y_pred)
plt.show()

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)

# %%
print(f"Root Mean Sqaured Error (RMSE): {rmse}")
print(f"R^2 score: {r2}")
# Out:
# Root Mean Sqaured Error (RMSE): 330685209.7187806
# R^2 score: 0.6474745689155845

# %%
X.columns
# Out:
# Index(['artist_count', 'in_spotify_playlists', 'in_spotify_charts',
#        'danceability_%', 'valence_%', 'energy_%', 'instrumentalness_%'],
#       dtype='object')

# %%
df.shape
# Out:
# (953, 13)

# %%
print("Prediction if a song will enter Billions Club or not\n")
song = input("Enter Name of New Song:")
artist_count = float(input("Enter Artist Count:"))
in_spotify_playlist = float(input("Enter In Spoify Playlist Count:"))
in_spotify_charts = float(input("Enter In Spotify Charts Count:"))
danceability = float(input("Enter Dancebility % :"))
valence = float(input("Enter Valence % :"))
energy = float(input("Enter Energy % :"))
instrumentalness = float(input("Enter instrumentalness % :"))
l = [artist_count,in_spotify_playlist,in_spotify_charts,danceability,valence,energy,instrumentalness]
new_data = np.array([l])
predicted_price = model.predict(new_data)
print(f"\nPredicted Number of Streams for New Song: {predicted_price[0]}\n")

if predicted_price[0]>1000000000:
    print("Yes , this song will enter Billions Club")
else:
    print("No , this song will not enter Billions Club")
# Out:
# Prediction if a song will enter Billions Club or not
# Enter Name of New Song: xsdsds
# Enter Artist Count: 1
# Enter In Spoify Playlist Count: 1000
# Enter In Spotify Charts Count: 20
# Enter Dancebility % : 71
# Enter Valence % : 23
# Enter Energy % : 71
# Enter instrumentalness % : 0
# Predicted Number of Streams for New Song: 316061621.7771243
#
# No , this song will not enter Billions Club
# C:\Users\ommic\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
